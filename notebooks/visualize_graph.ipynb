# %%
from IPython.display import display, Image

# %%
from healthcare_bot.main import graph_workflow

display(Image(graph_workflow.get_graph().draw_mermaid_png()))

# %%
demo = graph_workflow.invoke({"input": "I need to change my check-up appointment."})

# %%
print(demo["output"])
# Out:
# Sure, I can help you reschedule your check‑up. I’ll just need a few details first:
#
# 1. **Your full name (as it appears on the appointment).**
# 2. **Appointment reference/confirmation number** (if you have it).
# 3. **Current appointment date & time.**
# 4. **Preferred new date(s) and time(s)** (or a range of days that work for you).
# 5. **Preferred location/clinic** (if you have more than one option).
# 6. **How would you like to receive the updated confirmation?** (email, text message, or both).
#
# Once I have that information I’ll check availability and lock in a new slot for you. If you’d rather handle it directly through our online portal, just let me know and I can send you the link and quick steps.
#
# Feel free to share the details whenever you’re ready!
