# %%
from IPython.display import display, Image

# %%
from healthcare_bot.main import graph_workflow

display(Image(graph_workflow.get_graph().draw_mermaid_png()))

# %%
# demo = graph_workflow.invoke({"input": "I need to change my check-up appointment."})
demo = graph_workflow.invoke({"input": "I need to purchase medication."})

# %%
print(demo["decision"])
# Out:
# pharmacy_bot

# %%
print(demo["output"])
# Out:
# Hello! I’m happy to help you with getting the medication you need. To make sure I can give you the most accurate assistance, could you please let me know a few details?
#
# 1. **Medication name (brand or generic)**
# 2. **Strength and dosage form** (e.g., 10 mg tablet, 5 ml suspension)
# 3. **Do you already have a prescription from your provider?**
#    - If yes, is it a new prescription or a refill of an existing one?
# 4. **Any specific pharmacy location you’d like to use** (or would you like me to tell you our nearest store and hours)?
# 5. **Do you have insurance that you’d like to use for this purchase?**
#
# Once I have that information, I can:
#
# - Verify whether we have the medication in stock.
# - Explain the refill process (including any required authorization from your prescriber).
# - Provide our pharmacy’s hours, address, and options for pickup or delivery.
#
# Feel free to share as much as you’re comfortable with, and we’ll get you set up!
